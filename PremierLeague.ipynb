# %%
import sklearn
import numpy as np
import pandas as pd

# %%
epl_stats = pd.read_csv("epl_stats.csv")

# %%
epl_stats
# Out:
#                        team  apps  wins  draws  losses  goals_for  \
# 0                 Liverpool    12    11      1       0         28
# 1            Leicester City    12     8      2       2         29
# 2                   Chelsea    12     8      2       2         27
# 3           Manchester City    12     8      1       3         35
# 4          Sheffield United    12     4      5       3         13
# 5                   Arsenal    12     4      5       3         16
# 6         Manchester United    12     4      4       4         16
# 7   Wolverhampton Wanderers    12     3      7       2         16
# 8               Bournemouth    12     4      4       4         15
# 9                   Burnley    12     4      3       5         17
# 10   Brighton & Hove Albion    12     4      3       5         15
# 11           Crystal Palace    12     4      3       5         10
# 12         Newcastle United    12     4      3       5         11
# ...
